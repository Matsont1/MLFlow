# %%
import logging
import sys
import warnings
from urllib.parse import urlparse

import numpy as np
import pandas as pd
from sklearn.linear_model import ElasticNet,LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import mlflow
import mlflow.sklearn
from mlflow.models import infer_signature

# %%
logging.basicConfig(level=logging.WARN)
logger = logging.getLogger(__name__)


def eval_metrics(actual, pred):
    rmse = np.sqrt(mean_squared_error(actual, pred))
    mae = mean_absolute_error(actual, pred)
    r2 = r2_score(actual, pred)
    return rmse, mae, r2

# %%
if __name__ == "__main__":
    warnings.filterwarnings("ignore")
    np.random.seed(40)

    # Read the wine-quality csv file from the URL
    csv_url = (
        "https://raw.githubusercontent.com/mlflow/mlflow/master/tests/datasets/winequality-red.csv"
    )
    try:
        data = pd.read_csv(csv_url, sep=";")
    except Exception as e:
        logger.exception(
            "Unable to download training & test CSV, check your internet connection. Error: %s", e
        )

    # Split the data into training and test sets. (0.75, 0.25) split.
    train, test = train_test_split(data)

    # The predicted column is "quality" which is a scalar from [3, 9]
    train_x = train.drop(["quality"], axis=1)
    test_x = test.drop(["quality"], axis=1)
    train_y = train[["quality"]]
    test_y = test[["quality"]]

# %%
train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1316            5.4              0.74         0.00             1.2      0.041
# 1507            7.5              0.38         0.57             2.3      0.106
# 849             6.4              0.63         0.21             1.6      0.080
# 82              7.4              0.50         0.47             2.0      0.086
# 644             9.9              0.54         0.45             2.3      0.071
# ...             ...               ...          ...             ...        ...
# 1016            8.9              0.38         0.40             2.2      0.068
# 165             7.8              0.63         0.48             1.7      0.100
# 7               7.3              0.65         0.00             1.2      0.065
# 219             7.8              0.53         0.33             2.4      0.080
# 1350            9.0              0.60         0.29             2.0      0.069
#
# ...

# %%
alpha =  0.5
l1_ratio = 0.5

with mlflow.start_run():
        lr = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, random_state=42)
        lr.fit(train_x, train_y)

        predicted_qualities = lr.predict(test_x)

        (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

        print(f"Elasticnet model (alpha={alpha:f}, l1_ratio={l1_ratio:f}):")
        print(f"  RMSE: {rmse}")
        print(f"  MAE: {mae}")
        print(f"  R2: {r2}")

        mlflow.log_param("alpha", alpha)
        mlflow.log_param("l1_ratio", l1_ratio)
        mlflow.log_metric("rmse", rmse)
        mlflow.log_metric("r2", r2)
        mlflow.log_metric("mae", mae)

        predictions = lr.predict(train_x)
        signature = infer_signature(train_x, predictions)

        tracking_url_type_store = urlparse(mlflow.get_tracking_uri()).scheme

        # Model registry does not work with file store
        if tracking_url_type_store != "file":
            # Register the model
            # There are other ways to use the Model Registry, which depends on the use case,
            # please refer to the doc for more information:
            # https://mlflow.org/docs/latest/model-registry.html#api-workflow
            mlflow.sklearn.log_model(
                lr, "model", registered_model_name="ElasticnetWineModel", signature=signature
            )
        else:
            mlflow.sklearn.log_model(lr, "model", signature=signature)
# Out:
# 2025/09/26 23:24:19 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Elasticnet model (alpha=0.500000, l1_ratio=0.500000):
#   RMSE: 0.7931640229276851
#   MAE: 0.6271946374319586
#   R2: 0.10862644997792614
# 2025/09/26 23:24:26 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.

# %%
mlflow.sklearn.log_model(lr, "model", signature=signature)
# Out:
# 2025/09/26 23:24:26 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/09/26 23:24:29 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.

# %%
# !mlflow ui
# Out:
# ^C

# %%
from sklearn.linear_model import LinearRegression
with mlflow.start_run(run_name="model_1"):
    lr = LinearRegression().fit(train_x, train_y)
    predicted_qualities = lr.predict(test_x)
    (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

    print("Model 1")
    print(f"  RMSE: {rmse}")
    print(f"  MAE: {mae}")
    print(f"  R2: {r2}")

    mlflow.log_param("features", "x1")
    mlflow.log_metric("rmse", rmse)
    mlflow.log_metric("mae", mae)
    mlflow.log_metric("r2", r2)

    signature = infer_signature(train_x, lr.predict(train_x))
    mlflow.sklearn.log_model(lr, "model", signature=signature)
# Out:
# 2025/09/26 23:31:02 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Model 1
#   RMSE: 0.6603811224461618
#   MAE: 0.5073644199888921
#   R2: 0.3820931219110163
# 2025/09/26 23:31:06 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.

# %%
data = pd.read_csv("reg2.csv")

data = data[['y', 'x1', 'x2']].dropna()
train, test = train_test_split(data, test_size=0.25, random_state=42)

train_y = train['y']
test_y = test['y']

train_x1 = train[['x1']]
test_x1 = test[['x1']]

train_x2 = train[['x2']]
test_x2 = test[['x2']]

train_x12 = train[['x1', 'x2']]
test_x12 = test[['x1', 'x2']]

# %%
from sklearn.linear_model import LinearRegression
mlflow.set_experiment("Model 1")
mlflow.set_tracking_uri("http://127.0.0.1:5000/")
with mlflow.start_run(run_name="model_1"):
    lr = LinearRegression().fit(train_x1, train_y)
    predicted_qualities = lr.predict(test_x1)
    (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

    print("Model 1")
    print(f"  RMSE: {rmse}")
    print(f"  MAE: {mae}")
    print(f"  R2: {r2}")

    mlflow.log_param("features", "x1")
    mlflow.log_metric("rmse", rmse)
    mlflow.log_metric("mae", mae)
    mlflow.log_metric("r2", r2)

    signature = infer_signature(train_x1, lr.predict(train_x1))
    mlflow.sklearn.log_model(lr, "model", signature=signature)
# Out:
# 2025/09/26 23:47:17 INFO mlflow.tracking.fluent: Experiment with name 'Model 1' does not exist. Creating a new experiment.
# 2025/09/26 23:47:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Model 1
#   RMSE: 1.1425796554435663
#   MAE: 0.9516483716018922
#   R2: -0.008906761342932334
# 2025/09/26 23:47:21 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run model_1 at: http://127.0.0.1:5000/#/experiments/599283993365238178/runs/00a0c26ddf3e4065ace25b1b4d71bb00
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/599283993365238178

# %%
with mlflow.start_run(run_name="model_2"):
    lr = LinearRegression().fit(train_x2, train_y)
    predicted_qualities = lr.predict(test_x2)
    (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

    print("Model 1")
    print(f"  RMSE: {rmse}")
    print(f"  MAE: {mae}")
    print(f"  R2: {r2}")

    mlflow.log_param("features", "x1")
    mlflow.log_metric("rmse", rmse)
    mlflow.log_metric("mae", mae)
    mlflow.log_metric("r2", r2)

    signature = infer_signature(train_x2, lr.predict(train_x2))
    mlflow.sklearn.log_model(lr, "model", signature=signature)
# Out:
# 2025/09/26 23:47:37 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Model 1
#   RMSE: 1.185869214231059
#   MAE: 1.0030055857917803
#   R2: -0.08680505130228111
# 2025/09/26 23:47:41 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run model_2 at: http://127.0.0.1:5000/#/experiments/599283993365238178/runs/367eb161dda54eec840249006a5cd281
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/599283993365238178

# %%
with mlflow.start_run(run_name="model_3"):
    lr = LinearRegression().fit(train_x12, train_y)
    predicted_qualities = lr.predict(test_x12)
    (rmse, mae, r2) = eval_metrics(test_y, predicted_qualities)

    print("Model 1")
    print(f"  RMSE: {rmse}")
    print(f"  MAE: {mae}")
    print(f"  R2: {r2}")

    mlflow.log_param("features", "x1")
    mlflow.log_metric("rmse", rmse)
    mlflow.log_metric("mae", mae)
    mlflow.log_metric("r2", r2)

    signature = infer_signature(train_x12, lr.predict(train_x12))
    mlflow.sklearn.log_model(lr, "model", signature=signature)
# Out:
# 2025/09/26 23:47:43 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# Model 1
#   RMSE: 0.246022324179091
#   MAE: 0.19123591546897473
#   R2: 0.9532235678831984
# 2025/09/26 23:47:47 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 🏃 View run model_3 at: http://127.0.0.1:5000/#/experiments/599283993365238178/runs/45a4fdc7b42c4eec81317d06d985f42c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/599283993365238178

# %% [markdown]
# The results from the last one with X1 and X2 are much better than either of the previous 2

# %%
mlflow ui
# Out:
#   Cell In[25], line 1
#     mlflow ui
#            ^
# SyntaxError: invalid syntax
